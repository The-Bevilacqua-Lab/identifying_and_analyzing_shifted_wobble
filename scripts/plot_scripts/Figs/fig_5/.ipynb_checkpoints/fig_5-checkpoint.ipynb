# %%
import os
import pandas as pd
import csv
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#importing dataset of all shifted wobble
sw_df = pd.read_excel('Supplementary_file.xlsx', sheet_name='Table S1')

#filtering out the redundant ones (non-representative ones)
sw_df1= sw_df[sw_df['representative']==1]
sw_df1.index= np.arange(0, len(sw_df1))

# %%
print (sw_df1.columns.to_list())
# Out:
# ['PDB_ID', 'Experimental_Method', 'Resolution (Å)', 'chain_ID', 'seg_ID', 'Source_Organism_chain', 'Molecule', 'Source_Organism_all', 'Expressed_Organism', 'Chain_length_reference', 'Chain_length_structure', 'res_index_res1', 'bp_notation', 'res_ID_res1', 'res_index_res2', 'res_ID_res2', 'bp_res', 'bp_ID', 'b_resG', 'b_resU', 'b_comb', 'O6_O4_dih', 'N1_O2_dis', 'N1_N3_dis', 'N1_O4_dis', 'N2_O2_dis', 'N2_N3_dis', 'N2_O4_dis', 'O6_O2_dis', 'O6_N3_dis', 'O6_O4_dis', 'N1_O4_dih', 'N2_N3_dih', 'flank1', 'flank2', 'adj_res1', 'adj_res2', 'red_group_ID', 'number_of_group_members', 'missing_res_atoms', 'RMSD_to_avg', 'representative', 'G_N1_detail', 'G_N2_detail', 'G_N3_detail', 'G_O6_detail', 'G_N7_detail', "G_O2'_detail", "G_O4'_detail", 'U_O2_detail', 'U_N3_detail', 'U_O4_detail', "U_O2'_detail", "U_O4'_detail", 'G_N1_type', 'G_N2_type', 'G_N3_type', 'G_O6_type', 'G_N7_type', "G_O2'_type", "G_O4'_type", 'U_O2_type', 'U_N3_type', 'U_O4_type', "U_O2'_type", "U_O4'_type", 'combined_type', 'bp_1_above', 'bp_2_above', 'bp_1_below', 'bp_2_below', 'location_in_secondary_structure', 'Median_map_model_cc', 'Mean_map_model_cc', 'Raw_map_model_cc_for_the_G', 'Normalized_map_model_cc_for_the_G', 'Percentile_cc_for_the_G', 'Raw_map_model_cc_for_the_U', 'Normalized_map_model_cc_for_the_U', 'Percentile_cc_for_the_U', 'cluster']

# %%
cc_df_mean= sw_df1[['Normalized_map_model_cc_for_the_G', 'Raw_map_model_cc_for_the_G', 'Mean_map_model_cc', 'Raw_map_model_cc_for_the_U', 'Normalized_map_model_cc_for_the_U']].copy()
cc_df_mean.reset_index(drop=True, inplace=False)
# Out:
#     Normalized_map_model_cc_for_the_G  Raw_map_model_cc_for_the_G  \
# 0                                0.78                        0.61
# 1                                1.02                        0.91
# 2                                0.98                        0.78
# 3                                1.04                        0.82
# 4                                0.94                        0.74
# 5                                0.91                        0.67
# 6                                1.06                        0.91
# 7                                0.83                        0.71
# 8                                1.01                        0.83
# 9                                1.09                        0.81
# 10                               1.09                        0.81
# 11                               0.99                        0.92
# 12                               1.07                        0.95
# 13                               1.08                        0.83
# 14                               0.86                        0.64
# 15                               0.76                        0.59
# 16                               0.75                        0.62
# 17                               1.04                        0.83
# 18                               0.99                        0.92
# 19                               0.90                        0.74
# 20                               1.08                        0.91
# 21                               1.05                        0.88
# 22                               1.00                        0.60
# 23                               0.93                        0.78
# 24                               1.10                        0.91
# 25                               0.72                        0.55
# 26                               0.56                        0.46
# 27                               0.30                        0.08
# 28                               1.05                        0.82
# 29                               0.25                        0.20
# 30                               1.04                        0.75
# 31                               1.04                        0.93
# 32                               0.99                        0.74
# 33                               1.04                        0.84
# 34                               1.19                        0.83
# 35                               1.19                        0.83
# 36                               0.61                        0.46
# 37                               0.31                        0.19
# 38                               0.80                        0.48
# 39                               1.02                        0.84
# 40                               1.11                        0.93
#
#     Mean_map_model_cc  Raw_map_model_cc_for_the_U  \
# 0                0.78                        0.76
# 1                0.89                        0.92
# 2                0.80                        0.82
# 3                0.79                        0.82
# 4                0.79                        0.76
# 5                0.74                        0.72
# 6                0.86                        0.91
# 7                0.86                        0.78
# 8                0.82                        0.87
# 9                0.74                        0.81
# 10               0.74                        0.81
# 11               0.93                        0.89
# 12               0.89                        0.95
# 13               0.77                        0.85
# 14               0.74                        0.71
# 15               0.78                        0.45
# 16               0.83                        0.66
# 17               0.80                        0.80
# 18               0.93                        0.96
# 19               0.82                        0.73
# 20               0.84                        0.87
# 21               0.84                        0.89
# 22               0.60                        0.60
# 23               0.84                        0.77
# 24               0.83                        0.91
# 25               0.76                        0.47
# 26               0.82                        0.70
# 27               0.27                        0.24
# 28               0.78                        0.80
# 29               0.80                        0.25
# 30               0.72                        0.67
# 31               0.89                        0.84
# 32               0.75                        0.70
# 33               0.81                        0.85
# 34               0.70                        0.64
# 35               0.70                        0.64
# 36               0.76                        0.59
# 37               0.61                        0.07
# 38               0.60                        0.36
# 39               0.82                        0.84
# 40               0.84                        0.89
#
#     Normalized_map_model_cc_for_the_U
# 0                                0.97
# 1                                1.03
# 2                                1.02
# 3                                1.04
# 4                                0.96
# 5                                0.97
# 6                                1.06
# 7                                0.91
# 8                                1.06
# 9                                1.09
# 10                               1.09
# 11                               0.96
# 12                               1.07
# 13                               1.10
# 14                               0.96
# 15                               0.58
# 16                               0.80
# 17                               1.00
# 18                               1.03
# 19                               0.89
# 20                               1.04
# 21                               1.06
# 22                               1.00
# 23                               0.92
# 24                               1.10
# 25                               0.62
# 26                               0.85
# 27                               0.89
# 28                               1.03
# 29                               0.31
# 30                               0.93
# 31                               0.94
# 32                               0.93
# 33                               1.05
# 34                               0.91
# 35                               0.91
# 36                               0.78
# 37                               0.11
# 38                               0.60
# 39                               1.02
# 40                               1.06

# %%
emt_cls=[]

for i in range(1, 10):
    x1= np.repeat(' ', i)
    x2= ''.join(x1)
    emt_cls.append(x2)

print (len(emt_cls))
print ((emt_cls))
emt_df = pd.DataFrame(columns= emt_cls)
print (emt_df)
# Out:
# 9
# [' ', '  ', '   ', '    ', '     ', '      ', '       ', '        ', '         ']
# Empty DataFrame
# Columns: [ ,   ,    ,     ,      ,       ,        ,         ,          ]
# Index: []

# %%
sns.set(style= 'ticks', font= "Arial")
fig, ax = plt.subplots(figsize = (10,6), dpi = 400)


#fig= sns.stripplot(data= [cc_df_mean['Normalized_map_model_cc_for_the_G'], emt_df[emt_cls[0]], emt_df[emt_cls[1]], cc_df_mean['Raw_map_model_cc_for_the_G'], emt_df[emt_cls[2]], emt_df[emt_cls[3]], cc_df_mean['Mean_map_model_cc'], emt_df[emt_cls[4]], emt_df[emt_cls[5]],
#                          cc_df_mean['Raw_map_model_cc_for_the_U'], emt_df[emt_cls[6]], emt_df[emt_cls[7]], cc_df_mean['Normalized_map_model_cc_for_the_U']], 
#                          size= 15, jitter=0, alpha=0.5,  zorder=1, dodge= False,
#                          palette=['#4daf4a', 'W', 'W', '#4daf4a','W', 'W','#e41a1c', 'W','W',
#                                   '#a65628','W', 'W','#a65628'])

# X positions for the columns
x_positions = np.arange(len(cc_df_mean.columns))

colors= ['#4daf4a', '#4daf4a', '#e41a1c', '#a65628','#a65628']


# Set up the plot
#plt.figure(figsize=(8, 6))

# Plot scatter points and connect rows with lines
for i in range(len(cc_df_mean)):
    y_values = cc_df_mean.iloc[i]
    ax.plot(x_positions, y_values, marker='', color='gray', alpha=0.4, linestyle='-', linewidth=0.8, zorder= 1)
    
# Plot scatter points with distinct colors for each column
for x, col in enumerate(cc_df_mean.columns):
    ax.scatter(
        [x] * len(cc_df_mean), 
        cc_df_mean[col], 
        color=colors[x],
        edgecolor='none',
        s= 50,
        alpha=0.4, 
        zorder= 1,
        label=col if x == 0 else None  # Add label for legend only once
    )

# Overlay box plot for each column
PROPS = {
    'boxprops':{'facecolor':'None', 'edgecolor':'black', 'zorder':3},
    'medianprops':{'color':'black'},
    'whiskerprops':{'color':'black'},
    'capprops':{'color':'black'}
}

sns.boxplot(data=cc_df_mean, ax=ax, **PROPS, width=0.2, linewidth= 1,  showfliers=False)

l_counts=0
# Annotate above each x-axis tick
for i, label in enumerate(cc_df_mean.columns):
    # The annotation will be placed just above each x-axis tick
    l_counts +=1
    
    #ax.text(x_positions[i], max(cc_df_mean[label]) + 0.1, str(l_counts), ha='center', va='bottom', fontsize=11, color='black')
    ax.text(x_positions[i], 0.02, '('+ str(l_counts)+ ')', ha='center', va='bottom', fontsize=13, color='black')

    
# Customize the plot
x_labels= ['Normalized\nmap-model cc\nfor the G', 'Raw\nmap-model cc\nfor the G', 'Mean\nmap-model cc', 'Raw\nmap-model cc\nfor the U', 'Normalized\nmap-model cc\nfor the U']
ax.set_xticks(x_positions)
ax.set_xticklabels(x_labels, fontsize = 13)
ax.tick_params(axis='y', labelsize=13)
ax.set_ylabel("Map-model correlation coefficient", fontsize = 20)

ax= plt.gca()
ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)

# %%
cc_df_mean.columns
# Out:
# Index(['Normalized_map_model_cc_for_the_G', 'Raw_map_model_cc_for_the_G',
#        'Mean_map_model_cc', 'Percentile_cc_for_the_G',
#        'Raw_map_model_cc_for_the_U', 'Normalized_map_model_cc_for_the_U'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Example data
np.random.seed(42)
data = pd.DataFrame({
    'Column1': np.random.rand(10),
    'Column2': np.random.rand(10),
    'Column3': np.random.rand(10),
})

# Define colors for columns
colors = sns.color_palette("tab10", len(data.columns))

# Create the figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# X-axis positions for each column
x_positions = np.arange(len(data.columns))

# Plot scatter points and connect rows with lines
for i in range(len(data)):
    y_values = data.iloc[i]
    ax.plot(x_positions, y_values, marker='', color='gray', alpha=0.6, linestyle='-', linewidth=0.8)

# Plot scatter points with distinct colors for each column
for x, col in enumerate(data.columns):
    ax.scatter(
        [x] * len(data), 
        data[col], 
        color=colors[x], 
        alpha=0.8, 
        label=col if x == 0 else None  # Add label for legend only once
    )

# Overlay box plot for each column
sns.boxplot(data=data, ax=ax, width=0.5, showfliers=False, boxprops=dict(alpha=0.5), zorder=-1, palette=colors)

# Customize the plot
ax.set_xticks(x_positions)
ax.set_xticklabels(data.columns)
ax.set_title("Connected Jitter Plot with Box Plot")
ax.set_ylabel("Values")
ax.grid(True, linestyle='--', alpha=0.5)


# Adjust legend
handles = [plt.Line2D([0], [0], color=colors[i], marker='o', linestyle='None', label=data.columns[i]) for i in range(len(data.columns))]
ax.legend(handles=handles, title="Columns", loc='upper left')

# Show the plot
plt.tight_layout()
plt.show()
